# %% [markdown]
# # Image Application: cat or not?
#
# **After this assignment you will be able to:**
# - Build and apply a deep neural network to supervised learning.
# - Learn how to do data normalization
# - learn how to do weight initialization
# - Learn how to use regularization
#
# Let's get started!

# %% [markdown]
# ## 1 - Packages

# %% [markdown]
# **Exercise**: Please mount your Google drive, and set up your working folder here.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# start your code here
os.chdir("/content/drive/MyDrive/Deep Learning/Homework4/Homework4/regularization_tf") # change your working folder here
# end your code here

# %% [markdown]
# Let's first import all the packages that you will need during this assignment.
# - [numpy](https://www.numpy.org/) is the fundamental package for scientific computing with Python.
# - [matplotlib](http://matplotlib.org) is a library to plot graphs in Python.
# - [h5py](http://www.h5py.org) is a common package to interact with a dataset that is stored on an H5 file.
# - [PIL](http://www.pythonware.com/products/pil/) and [scipy](https://www.scipy.org/) are used here to test your model with your own picture at the end.
# - dnn_app_utils provides the customized functions that will be used in this notebook.
# - np.random.seed(1) is used to keep all the random function calls consistent. It will help us grade your work.

# %%
import time
import numpy as np
import tensorflow as tf
import h5py
import matplotlib.pyplot as plt
import dnn_app_utils_v3 as du
from skimage.transform import rescale, resize, downscale_local_mean

# refresh 'planar_utils' module
import imp
imp.reload(du)

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

np.random.seed(1)
tf.random.set_seed(1)

# %% [markdown]
# ## 2 - Dataset
#
# **Problem Statement**: You are given a dataset ("data.h5") containing:
#     - a training set of m_train images labelled as cat (1) or non-cat (0)
#     - a test set of m_test images labelled as cat and non-cat
#     - each image is of shape (num_px, num_px, 3) where 3 is for the 3 channels (RGB).
#
# Let's get more familiar with the dataset. Load the data by running the cell below.
#
# The training input and output are stored in 'train_x_orig' and 'train_y'. The test input and output are stored in 'test_x_orig' and 'test_y'.

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = du.load_data()
train_y = train_y.reshape(209,1)
test_y = test_y.reshape(50,1)
#print(classes)

# %% [markdown]
# The following code will show you an image in the dataset. Feel free to change the index and re-run the cell multiple times to see other images.

# %%
# Example of a picture
index = 169
plt.imshow(train_x_orig[index])
print("y = " + str(train_y[index,0]) + ". It's a " + classes[train_y[index,0]].decode("utf-8") +  " picture.")
#print(train_x_orig[index].shape,train_x_orig[index])
# Out:
# y = 1. It's a cat picture.

# %% [markdown]
# Let's explore more about the training data. We are curious about the shape of each image and can use 'train_x_orig[index].shape' to expore it.
# **Exercise**: Can you tell what the pixel number of each image is?

# %%
# Explore your dataset 
image_shape=train_x_orig[index].shape
print("Each image is of size: ", image_shape)
#start your code here
num_px=209   # the number of pixels in each column of the image. Hint: The 1st element in image_shape indicates this number?
#end your code here
print('Number of pixels in each column of the image:', num_px)
# Out:
# Each image is of size:  (64, 64, 3)
# Number of pixels in each column of the image: 209

# %% [markdown]
# We just take a close look at an image of the image set. Now, let's take a look at the whole training set.
#
# **Exercise**: The first 4 lines in the following cell print out the shape of the trining images. There are 209 images, and each image has 64 by 64 pixcels and GRB color.
#
# Please print out the shape of the test input (stored in `test_x_orig`) and output (stored in `test_y`) data, and tell how many images we have in the test data.

# %%
train_x_shape=train_x_orig.shape
m_train = train_x_shape[0]
print ("train_x_orig shape: ",train_x_shape)
print ("Number of training examples: " ,m_train)
# start your code here
test_x_shape= test_x_orig.shape
test_y_shape= test_y.shape
m_test = test_x_shape[0]
# end your code here

print ("test_x_orig shape: " ,test_x_shape)
print ("test_y shape: " , test_y_shape)
print ("Number of test examples: " ,m_test)
# Out:
# train_x_orig shape:  (209, 64, 64, 3)
# Number of training examples:  209
# test_x_orig shape:  (50, 64, 64, 3)
# test_y shape:  (50, 1)
# Number of test examples:  50

# %% [markdown]
# As mentioned in our lecture, you reshape and standardize the images before feeding them to the network. The code is given in the cell below.
#
# ![alt text](https://drive.google.com/uc?id=12XXwVJpcT-moegSdzejC-W-hD79qDSk9)
# <caption><center> <u>Figure 1</u>: Image to vector conversion. <br> </center></caption>

# %%
# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_shape[0], -1)   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1)

# %% [markdown]
# Data normalization can help us accelerate the training process. The RGB values of an image are integers in the range of [0,255]. We can normalize the training images to have the feature values between 0 and 1 by using `train_x = train_x_flatten/255.0`.
#
# **Exercise**: We normalize the training images using `train_x = train_x_flatten/255.0` in the 1st line. Please normalize the test images to have feature values between 0 and 1.

# %%
# Standardize data to have feature values between 0 and 1.
train_x = train_x_flatten/255.0

#start your code here
test_x = test_x_flatten/255.0
#end your code here

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
print ("train_y's shape: " + str(train_y.shape))
print ("test_y's shape: " + str(test_y.shape))
# Out:
# train_x's shape: (209, 12288)
# test_x's shape: (50, 12288)
# train_y's shape: (209, 1)
# test_y's shape: (50, 1)

# %% [markdown]
# ###3- Build your neural network ###
# Now, we are going to use the skills in the first module to build our neural network.
#
# Excep the input layer, you can use
#
# `tf.keras.layers.Dense(20,activation='relu',
#                             kernel_initializer='glorot_uniform',
#                             bias_initializer='zeros')`
#
# to build the layers. In this example, we have 20 neurons in this layer, use 'relu' as the activation function, initialize our weight randomly using 'glorot_uniform', and our bias is initialized to be 'zeros'.
#
# First, we will need an input layer. How many neurons will you need in the input layer? Hint: how many elements does every training input have?
#
# Second, we will build several hidden layers. You are free to choose the number of neurons in every hidden layer.
#
# Last, we will build the output layer. How many neurons will you need in the output layer? Which activation function is more suitale in this problem? Hint: how many elements does every training output have? What is the range of the training output?

# %%
tf.random.set_seed(1) # we fixed the seed of the random number generator, so every time running this code, we can have the same results.

# start your code here
cat_model=tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(12288,)), # how many elements are there in every training image?
    tf.keras.layers.Dense(20,activation='relu', # in layer 1, we will have 20 neurons and use 'relu' as the activation function
                            kernel_initializer='glorot_uniform', # we will randomly choose the initial weight using the 'glorot_uniform' method
                            bias_initializer='zeros'), # we will initialize all bias to be zeros.
    #please follow the example of layer 1 to add more hidden layers here. 
    tf.keras.layers.Dense(20,activation='relu', 
                            kernel_initializer='glorot_uniform', 
                            bias_initializer='zeros'), 
    # End adding hidden layers                    
    tf.keras.layers.Dense(1,activation='sigmoid', # how many elements are there in every training output
                            kernel_initializer='glorot_uniform',
                            bias_initializer='zeros'),
])
# end your code here
cat_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                245780
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dense_2 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 246,221
# Trainable params: 246,221
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, let's compile the model. When comiling your model, you will need to specify the optimizer, the loss function, and the metrics.
#
# For optimizers, the most popular ones are 'Adam' and its derivatives. You can also try 'RMSprop' and 'SGD' to see which one works better for you. You might need adjust the learning rate to acceperate the training process.
#
# For loss functions, our problem is a two-class classification problem. The most popular loss function would be 'BinaryCrossentropy'. If this is a multiple-class classification problem, you probably want to try 'CategoricalCrossentropy' or 'SparseCategoricalCrossentropy'.
#
# For the metrics, we want to know the accuracy of our model. Therefore, I would recommend 'accuracy'.

# %%
# start your code here
cat_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),  # Optimizer. Please change 'None' to some meaningful learning rate which is usually <1
    # Loss function to minimize
    loss=tf.keras.losses.BinaryCrossentropy(),
    # List of metrics to monitor
    metrics=['accuracy'],
                 )
# end your code here

# %% [markdown]
# It's time to train.
#
# We can plot training history. It can help us to adjust the parameters.
#
# If the training loss increases, we may want to decrease the `learning_rate`.
#
# If the training loss has large vibration, we may want to decrease the `learning_rate`.
#
# If the training loss decreases too slowly, we need to increase `learning_rate`.
#
# If the training loss decreases at a good speed, but ends up large, we may want to increase the epoch number.

# %%
# start your code here
history = cat_model.fit(
    train_x, # input data
    train_y, # real output data
    validation_split=0.15, # this number is usually betwwen 0 and 0.3. It is the portion used as validation data, 
    epochs=10, # how many iterations do you want to train your model? Your data will be reused to train the model for the number of epochs. I trained 5 min for this model
)
# end your code here. 
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss','val_loss'])
# Out:
# Epoch 1/10
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5716 - accuracy: 0.7232 - val_loss: 0.6797 - val_accuracy: 0.5938
# Epoch 2/10
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5226 - accuracy: 0.7571 - val_loss: 0.5948 - val_accuracy: 0.7500
# Epoch 3/10
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5295 - accuracy: 0.7401 - val_loss: 0.6114 - val_accuracy: 0.7188
# Epoch 4/10
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5041 - accuracy: 0.7740 - val_loss: 0.5931 - val_accuracy: 0.7500
# Epoch 5/10
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5355 - accuracy: 0.7006 - val_loss: 0.8162 - val_accuracy: 0.5312
# Epoch 6/10
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5284 - accuracy: 0.7514 - val_loss: 0.5933 - val_accuracy: 0.7500
# Epoch 7/10
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4866 - accuracy: 0.7797 - val_loss: 0.6138 - val_accuracy: 0.5938
# Epoch 8/10
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4454 - accuracy: 0.7740 - val_loss: 0.7637 - val_accuracy: 0.5000
# Epoch 9/10
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4843 - accuracy: 0.7797 - val_loss: 0.7020 - val_accuracy: 0.7500
# Epoch 10/10
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4893 - accuracy: 0.7458 - val_loss: 0.7758 - val_accuracy: 0.5625

# %% [markdown]
# ### 4. test ###
# Let us test their performance using our test dataset. The test dataset is never used to train the models, and reflects the acutual performance of the model when it is used in the general images.
#
# To evaluate the model , we can use
# `cat_model.evaluate(test_x,test_y)`.

# %%
cat_model.evaluate(test_x,test_y)
# Out:
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5659 - accuracy: 0.7600
# [0.5658571720123291, 0.7599999904632568]

# %% [markdown]
# The expected accuracy is higher than 0.7. If the accuracy is lower than 0.7, you may want to increase the epoch number, adjust the learning rate, and the regularizer weight, to achieve the goal.
#
# For your reference, I trained the model for 5 min to achieve that goal.
#
# If you have achieved the 0.7 goal, I would like to challenge you for the 0.8 accuracy for the test set.

# %% [markdown]
# ### 5- Adding Regularization ###
# After enough training, you probably notice that while the training loss is very small, the validation loss is quite large. This is what we called **low bias high vairance** problem. We have several ways to deal with it,
# 1. L1/L2 regularization,
# 2. drop out, and
# 3. early stop.
#
# I would recommend you try the regularization first, because it's easy to use and usually works.
#
# To add regularization to the network, we only need to specify this option in the 'Dense' layer as follows.
#
# `tf.keras.layers.Dense(20,activation='relu',
#                           kernel_initializer='glorot_uniform',
#                           bias_initializer='zeros',
#                           kernel_regularizer=tf.keras.regularizers.L2(0.01))`
#
# The parameter **kernel_regularizer=tf.keras.regularizers.L2(0.01)** says that we want an 'L2' regularizer with weight 0.01. A higher weight usually can reduce the validation loss more. But if the weight is too large, the training loss might redecus very slowly.

# %%
tf.random.set_seed(1)
cat_model_regu=tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(12288,)),
    tf.keras.layers.Dense(20,activation='relu', # in layer 1, we will have 20 neurons and use 'relu'
                          kernel_initializer='glorot_uniform',# we will randomly choose the initial weight using the 'glorot_uniform' method as the activation function
                          bias_initializer='zeros', # we will initialize all bias to be zeros.
                          kernel_regularizer=tf.keras.regularizers.L2(0.05)), # L2-regularization can be added here
    #please feel free to add more hidden layers with regularizer
    
    # End adding hidden layers 
    tf.keras.layers.Dense(1,activation='sigmoid', 
                            kernel_initializer='glorot_uniform',
                            bias_initializer='zeros', 
                            kernel_regularizer=tf.keras.regularizers.L2(0.05)),
])

cat_model_regu.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 20)                245780
#
#  dense_4 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 245,801
# Trainable params: 245,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, you can compile and train the regularized neural network as before.

# %%
# start your code here
cat_model_regu.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),  # Optimizer please change "None" to some meaningful number here
    # Loss function to minimize
    loss=tf.keras.losses.BinaryCrossentropy(),
    # List of metrics to monitor
    metrics=['accuracy'],
                 )
# end your code here.

# %%
# start your code here
history_regu = cat_model_regu.fit(
    train_x, # input data
    train_y, # real output data
    validation_split=0.15, # this number is usually betwwen 0 and 0.3. It is the portion used as validation data, 
    epochs=150, # how many iterations do you want to train your model? Your data will be reused to train the model for the number of epochs. I trained 5 min for this model
)
# end your code here

plt.figure()
plt.plot(history_regu.history['loss'])
plt.plot(history_regu.history['val_loss'])
plt.legend(['loss','val_loss'])
# Out:
# Epoch 1/150
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3338 - accuracy: 0.9944 - val_loss: 0.9305 - val_accuracy: 0.5625
# Epoch 2/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3404 - accuracy: 0.9944 - val_loss: 0.9288 - val_accuracy: 0.5625
# Epoch 3/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3425 - accuracy: 0.9774 - val_loss: 0.9296 - val_accuracy: 0.5312
# Epoch 4/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3377 - accuracy: 0.9831 - val_loss: 0.9368 - val_accuracy: 0.5625
# Epoch 5/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3471 - accuracy: 0.9831 - val_loss: 0.9515 - val_accuracy: 0.5312
# Epoch 6/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3444 - accuracy: 0.9774 - val_loss: 0.9319 - val_accuracy: 0.5625
# Epoch 7/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3398 - accuracy: 0.9887 - val_loss: 0.9300 - val_accuracy: 0.5312
# Epoch 8/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3423 - accuracy: 0.9887 - val_loss: 0.9294 - val_accuracy: 0.5625
# Epoch 9/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3439 - accuracy: 0.9831 - val_loss: 0.9369 - val_accuracy: 0.5625
# Epoch 10/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3384 - accuracy: 0.9774 - val_loss: 0.9374 - val_accuracy: 0.5625
# Epoch 11/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3358 - accuracy: 0.9887 - val_loss: 0.9353 - val_accuracy: 0.5625
# Epoch 12/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3346 - accuracy: 0.9944 - val_loss: 0.9408 - val_accuracy: 0.5625
# Epoch 13/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3357 - accuracy: 0.9944 - val_loss: 0.9407 - val_accuracy: 0.5625
# Epoch 14/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3366 - accuracy: 0.9944 - val_loss: 0.9419 - val_accuracy: 0.5625
# Epoch 15/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3374 - accuracy: 1.0000 - val_loss: 0.9389 - val_accuracy: 0.5625
# Epoch 16/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3330 - accuracy: 0.9944 - val_loss: 0.9291 - val_accuracy: 0.5625
# Epoch 17/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3335 - accuracy: 0.9944 - val_loss: 0.9354 - val_accuracy: 0.5625
# Epoch 18/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3339 - accuracy: 0.9944 - val_loss: 0.9417 - val_accuracy: 0.5625
# Epoch 19/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3343 - accuracy: 0.9944 - val_loss: 0.9362 - val_accuracy: 0.5625
# Epoch 20/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3325 - accuracy: 0.9944 - val_loss: 0.9275 - val_accuracy: 0.5625
# Epoch 21/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3335 - accuracy: 0.9944 - val_loss: 0.9336 - val_accuracy: 0.5625
# Epoch 22/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3354 - accuracy: 0.9887 - val_loss: 0.9320 - val_accuracy: 0.5625
# Epoch 23/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3348 - accuracy: 0.9944 - val_loss: 0.9334 - val_accuracy: 0.5625
# Epoch 24/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3373 - accuracy: 0.9944 - val_loss: 0.9331 - val_accuracy: 0.5625
# Epoch 25/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.
150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3349 - accuracy: 0.9944 - val_loss: 0.9516 - val_accuracy: 0.5625
# Epoch 58/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3396 - accuracy: 0.9944 - val_loss: 0.9519 - val_accuracy: 0.5312
# Epoch 59/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3332 - accuracy: 0.9887 - val_loss: 0.9468 - val_accuracy: 0.5625
# Epoch 60/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3371 - accuracy: 0.9887 - val_loss: 0.9543 - val_accuracy: 0.5000
# Epoch 61/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3386 - accuracy: 0.9887 - val_loss: 0.9516 - val_accuracy: 0.5625
# Epoch 62/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3362 - accuracy: 0.9831 - val_loss: 0.9715 - val_accuracy: 0.5000
# Epoch 63/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3414 - accuracy: 0.9887 - val_loss: 0.9475 - val_accuracy: 0.5625
# Epoch 64/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3359 - accuracy: 0.9887 - val_loss: 0.9518 - val_accuracy: 0.5000
# Epoch 65/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3294 - accuracy: 0.9944 - val_loss: 0.9464 - val_accuracy: 0.5625
# Epoch 66/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3349 - accuracy: 0.9944 - val_loss: 0.9530 - val_accuracy: 0.4688
# Epoch 67/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3371 - accuracy: 0.9887 - val_loss: 0.9442 - val_accuracy: 0.5625
# Epoch 68/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3296 - accuracy: 0.9944 - val_loss: 0.9634 - val_accuracy: 0.4688
# Epoch 69/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3328 - accuracy: 0.9944 - val_loss: 0.9571 - val_accuracy: 0.5625
# Epoch 70/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3381 - accuracy: 0.9887 - val_loss: 0.9793 - val_accuracy: 0.5000
# Epoch 71/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3595 - accuracy: 0.9605 - val_loss: 0.9612 - val_accuracy: 0.6250
# Epoch 72/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3606 - accuracy: 0.9322 - val_loss: 0.9811 - val_accuracy: 0.5000
# Epoch 73/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3691 - accuracy: 0.9661 - val_loss: 0.9535 - val_accuracy: 0.6250
# Epoch 74/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3437 - accuracy: 0.9831 - val_loss: 0.9671 - val_accuracy: 0.5000
# Epoch 75/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3419 - accuracy: 0.9831 - val_loss: 0.9469 - val_accuracy: 0.5625
# Epoch 76/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3382 - accuracy: 0.9831 - val_loss: 0.9558 - val_accuracy: 0.5000
# Epoch 77/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3351 - accuracy: 0.9831 - val_loss: 0.9552 - val_accuracy: 0.5625
# Epoch 78/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3396 - accuracy: 0.9831 - val_loss: 0.9610 - val_accuracy: 0.4688
# Epoch 79/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3327 - accuracy: 0.9887 - val_loss: 0.9517 - val_accuracy: 0.5625
# Epoch 80/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3458 - accuracy: 0.9887 - val_loss: 0.9694 - val_accuracy: 0.5000
# Epoch 81/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3391 - accuracy: 0.9887 - val_loss: 0.9600 - val_accuracy: 0.6250
# Epoch 82/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3393 - accuracy: 0.9887 - val_loss: 0.9612 - val_accuracy: 0.4688
# Epoch 83/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3297 - accuracy: 0.9944 - val_loss: 0.9438 - val_accuracy: 0.5625
# Epoch 84/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3325 - accuracy: 0.9944 - val_loss: 0.9436 - val_accuracy: 0.5625
# Epoch 85/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3273 - accuracy: 0.9944 - val_loss: 0.9468 - val_accuracy: 0.5625
# Epoch 86/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3329 - accuracy: 0.9944 - val_loss: 0.9551 - val_accuracy: 0.5312
# Epoch 87/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3294 - accuracy: 0.9944 - val_loss: 0.9529 - val_accuracy: 0.5625
# Epoch 88/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3281 - accuracy: 0.9944 - val_loss: 0.9589 - val_accuracy: 0.5625
# Epoch 89/150
# 6/6 [==============================] - 0s 14ms/step - loss: 0.
150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3338 - accuracy: 0.9774 - val_loss: 0.9652 - val_accuracy: 0.5000
# Epoch 123/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3321 - accuracy: 0.9831 - val_loss: 0.9589 - val_accuracy: 0.5625
# Epoch 124/150
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3267 - accuracy: 0.9944 - val_loss: 0.9730 - val_accuracy: 0.4688
# Epoch 125/150
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3333 - accuracy: 0.9887 - val_loss: 0.9654 - val_accuracy: 0.5625
# Epoch 126/150
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3301 - accuracy: 0.9887 - val_loss: 0.9596 - val_accuracy: 0.5625
# Epoch 127/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3278 - accuracy: 0.9944 - val_loss: 0.9560 - val_accuracy: 0.5625
# Epoch 128/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3309 - accuracy: 0.9944 - val_loss: 0.9534 - val_accuracy: 0.5625
# Epoch 129/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3315 - accuracy: 0.9887 - val_loss: 0.9701 - val_accuracy: 0.5000
# Epoch 130/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3347 - accuracy: 0.9944 - val_loss: 0.9584 - val_accuracy: 0.5625
# Epoch 131/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3287 - accuracy: 0.9944 - val_loss: 0.9599 - val_accuracy: 0.5625
# Epoch 132/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3262 - accuracy: 1.0000 - val_loss: 0.9580 - val_accuracy: 0.5625
# Epoch 133/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3255 - accuracy: 0.9944 - val_loss: 0.9555 - val_accuracy: 0.5625
# Epoch 134/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3252 - accuracy: 0.9944 - val_loss: 0.9552 - val_accuracy: 0.5625
# Epoch 135/150
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3287 - accuracy: 0.9944 - val_loss: 0.9618 - val_accuracy: 0.5625
# Epoch 136/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3255 - accuracy: 0.9944 - val_loss: 0.9740 - val_accuracy: 0.5000
# Epoch 137/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3337 - accuracy: 0.9944 - val_loss: 0.9633 - val_accuracy: 0.5625
# Epoch 138/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3316 - accuracy: 0.9831 - val_loss: 0.9625 - val_accuracy: 0.5625
# Epoch 139/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3339 - accuracy: 1.0000 - val_loss: 0.9573 - val_accuracy: 0.5625
# Epoch 140/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3323 - accuracy: 0.9944 - val_loss: 0.9598 - val_accuracy: 0.5625
# Epoch 141/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3282 - accuracy: 0.9944 - val_loss: 0.9679 - val_accuracy: 0.5625
# Epoch 142/150
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3274 - accuracy: 0.9944 - val_loss: 0.9646 - val_accuracy: 0.5625
# Epoch 143/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3445 - accuracy: 0.9774 - val_loss: 0.9764 - val_accuracy: 0.5000
# Epoch 144/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3361 - accuracy: 0.9831 - val_loss: 0.9599 - val_accuracy: 0.5625
# Epoch 145/150
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3330 - accuracy: 0.9887 - val_loss: 0.9643 - val_accuracy: 0.5625
# Epoch 146/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3352 - accuracy: 0.9944 - val_loss: 0.9814 - val_accuracy: 0.5000
# Epoch 147/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3378 - accuracy: 0.9887 - val_loss: 0.9713 - val_accuracy: 0.5625
# Epoch 148/150
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3292 - accuracy: 0.9944 - val_loss: 0.9691 - val_accuracy: 0.5625
# Epoch 149/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3246 - accuracy: 0.9944 - val_loss: 0.9731 - val_accuracy: 0.5625
# Epoch 150/150
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3238 - accuracy: 0.9944 - val_loss: 0.9734 - val_accuracy: 0.5625

# %% [markdown]
# After the training, we can evaluate the regularized NN use the following command.

# %%
cat_model_regu.evaluate(test_x,test_y)
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8915 - accuracy: 0.7000
# [0.8914546966552734, 0.699999988079071]

# %% [markdown]
# The expected accuracy is highter than 0.8.
