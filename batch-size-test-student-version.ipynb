# %%
from google.colab import drive
drive.mount('/content/drive')
import os
# start your code here
os.chdir("/content/drive/MyDrive/Deep Learning/Homework5/Homework5") # change your working folder here
# end your code here
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 0. Batch size and epochs
#
# When you train your model in TensorFlow, there is a parameter called batch-size, which is quite helpful in accelerating and stabilizing the learning process.
#
# ```
# model.fit(trainX, trainY, epochs=200, batch_size=64)
# ```
# Here, 'epochs=200' means that you will reuse your data set for 200 times to train the neural network.
#
# 'batch_size=64' means that in every epoch you are going to update your weights and bias once every 64 samples. If there is not enough samples left in the last batch, you will use the leftovers to update the weights and bias for the last time in this epoch.

# %% [markdown]
# ## 1. Batch, Stochastic, and Minibatch Gradient Descent Method.
#
# ###1.1 (Batch) Gradient Descent
#
# At the very beginning of this course, we introduced the gradient descent (GD) method, which is for $l = 1, ..., L$:
# $$ W^{[l]} = W^{[l]} - \alpha \text{ } dW^{[l]} \tag{1}$$
# $$ b^{[l]} = b^{[l]} - \alpha \text{ } db^{[l]} \tag{2}$$
#
# where L is the number of layers and $\alpha$ is the learning rate. For the ith sample, we can compute a derivative $dW^{[l](i)}$ and $db^{[l](i)}$. The derivaties $dW^{[l]}$ and $db^{[l]}$ are the average of $dW^{[l](i)}$ and $db^{[l](i)}$ for all samples. This method is also called the batch gradient descent method. If you want to use (batch) gradient method, the batch_size can be set to the number of samples.
# ```
# model.fit(trainX, trainY, epochs=200, batch_size=trainX.shape[0])
# ```
#
# ### 1.2 Stochastic Gradient Descent
# Stochastic gradient descent (SGD) method still use equation (1) and (2) to update the weights and bias. The difference is that instead of using the average gradient of all samples to update the weights and bias once for every epoch, SGD updates the weights and bias once for every sample using the derivatives of that sample. Assuming there are $m$ samples, SGD will update the weights and bias for m times. If SGD is used, the batch_size is set to be 1.
#
# ```
# model.fit(trainX, trainY, epochs=200, batch_size=1)
# ```
#
# ### 1.3 Mini-Batch Gradient Descent
# Mini-batch gradient descent (mini-batch GD) is something in between. In every epoch, GD updates too few times while SGD updates too many times. Mini-batch GD sets its batch_size somewhere between 1 and m, and generally provides faster training process.
# ```
# model.fit(trainX, trainY, epochs=200, batch_size=64)
# ```
# In Tensorflow, the default value for `batch_size` is 32. If you don't specify the batch_size, your batch_size is 32. The value of it is usually set to be the power of 2 to accommodate the binary property of CPU and GPU.

# %% [markdown]
# ## 2. Testing batch_size on A Multi-Class Classification Problem
#
# ### 2.1 A Multi-Class Classification Problem
# We will use a small multi-class classification problem as the basis to demonstrate the effect of batch size on learning.
#
# The scikit-learn class provides the `make_blobs()` function that can be used to create a multi-class classification problem with the prescribed number of samples, input variables, classes, and variance of samples within a class.
#
# The problem can be configured to have two input variables (to represent the x and y coordinates of the points, 'n_features') and a standard deviation of 2.0 for points within each group. We will use the same random state (seed for the pseudorandom number generator) to ensure that we always get the same data points.

# %%
# scatter plot of blobs dataset
from sklearn.datasets import make_blobs
from matplotlib import pyplot
import numpy as np
import tensorflow as tf
# generate 2d classification dataset
X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=2) # 'n_samples: how many data points', 'centers: how many classes', 'n_features: how many element in every sample input', 'cluster_std: standard deviation of every classs', 'random_state: random seed for pseudorandom number generator'
# scatter plot for each class value
colors = ["r", "yellow", "g"]
for class_value in range(3):
	# select indices of points with the class label
	row_ix = np.where(y == class_value)
	# scatter plot for points with a different color
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1],color=colors[class_value])
# show plot
pyplot.show()

# %% [markdown]
# For multi-class classification problems, we usually transform the label of every sample (point) y to a one-hot vector. For example, 'red' (y=0) is [1 0 0], 'yellow' (y=1) is [0 1 0], and 'green' (y=2) is [0 0 1]. Because every vector has only 1 non-zero value, it is called a 'one-hot' vector.
# ![alt text](https://etlpoint.com/wp-content/uploads/2020/07/77.png)
#
# In tensorflow, we can tranform the labels of samples to one hot vectors by calling
#
# ```
# tf.keras.utils.to_categorical(y)
# ```
# Please transform the lables (or the output of the dataset) to one hot vectors.

# %%
# transform multi-class lables to one hot vectors
# start your code here
y_one_hot= tf.keras.utils.to_categorical(y) # please replace None by a meaningful command
# end your code here
print('The dimension of input data is', X.shape)
print('The dimension of transformed output is', y_one_hot.shape)
print('The 3rd sample is green:',y_one_hot[2,:])
# Out:
# The dimension of input data is (1000, 2)
# The dimension of transformed output is (1000, 3)
# The 3rd sample is green: [0. 0. 1.]

# %% [markdown]
# The expected output:
# ```
# The dimension of transformed lables is (1000, 3)
# The 3rd sample is green: [0. 0. 1.]
# ```

# %% [markdown]
# ### 2.2 Building neural network
# We are going to build a shallow neural network to distinguish the 3 classes. Please use `functional API' to build a nerual network with
#
# 1. an input layer with appropriate shape
# 2. a hidden layer with 50 neurons and activation function 'relu'
# 3. an output layer with appropriate number of neurons and activation function 'softmax'.
#
# Softmax function is usually used in the output layer in multi-class claasification problems.

# %%
# start your code here
inputs= tf.keras.Input(shape=2)  # please replace None by a meaningful command
hidden= tf.keras.layers.Dense(50, activation=tf.nn.relu)(inputs) # please replace None by a meaningful command
outputs=tf.keras.layers.Dense(3, activation=tf.nn.softmax)(hidden) # please replace None by a meaningful command
#end your code here
model=tf.keras.models.Model(inputs=inputs,outputs=outputs,name='shallow_model')
model.summary()
model.save('initial_model')
# Out:
# Model: "shallow_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 2)]               0
#
#  dense_8 (Dense)             (None, 50)                150
#
#  dense_9 (Dense)             (None, 3)                 153
#
# =================================================================
# Total params: 303
# Trainable params: 303
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: initial_model/assets

# %% [markdown]
# Expected output:
# ```
# Model: "shallow_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 2)]               0
#
#  hidden_layer (Dense)        (None, 50)                150
#
#  output_layer (Dense)        (None, 3)                 153
#
# =================================================================
# Total params: 303
# Trainable params: 303
# Non-trainable params: 0
# _________________________________________________________________
# ```

# %% [markdown]
# ### 2.3 Compiling and fitting neural network using batch GD
# We first use batch GD to train the neurual network. Please make sure that the batch_size is the number of samples in the training data. If you set batch_size greater than the number of samples in the training data, the batch_size will be automatically adjusted to this number.
#
# The model will be trained for 200 epochs, and we split 20% of the data for validation.

# %%
import time
modelGD=tf.keras.models.load_model('initial_model')
modelGD.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.SGD(learning_rate=0.1), metrics=['accuracy'])
start_time = time.time()
# start your code here
historyGD = modelGD.fit(
    train_dataset, 
    epochs=100, 
    validation_data=test_dataset) #please replace None by something meaningful
# end your code here
print("Time taken: %.2fs" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f2518ae50f6c> in <module>()
#       1 import time
# ----> 2 modelGD=tf.keras.models.load_model('initial_model')
#       3 modelGD.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.SGD(learning_rate=0.1), metrics=['accuracy'])
#       4 start_time = time.time()
#       5 # start your code here
#
# NameError: name 'tf' is not defined

# %% [markdown]
# Expected output for the 1st 3 epochs:
# ```
# Epoch 1/200
# 1/1 [==============================] - 1s 540ms/step - loss: 2.2440 - accuracy: 0.3363 - val_loss: 1.0965 - val_accuracy: 0.3750
# Epoch 2/200
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1960 - accuracy: 0.3487 - val_loss: 0.8725 - val_accuracy: 0.5550
# Epoch 3/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9020 - accuracy: 0.5475 - val_loss: 0.8096 - val_accuracy: 0.5450
# ...
# Time taken: 11.34s
# ```
# Your loss, accuracy, val_loss, and val_accuracy may be different, but we shall see
# ` 1/1 [==============================]` appears for every epoch and the time taken is similar. It indicates that you have 1 batch for every epoch.
#
# The final 'accuracy' and 'val_accuracy' should be greater than `0.8`.

# %% [markdown]
# Now, let's print out the training history to see how the training process looks like.

# %%
from matplotlib import pyplot
# plot training history
pyplot.plot(historyGD.history['accuracy'], label='train')
pyplot.plot(historyGD.history['val_accuracy'], label='validation')
pyplot.xlabel('epoch number')
pyplot.ylabel('accuracy')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ### 2.4 Compiling and fitting neural network using stochastic gradient descent
# We will reload the untrained model and train it using stochastic gradient descent method. In this case, we will update the weights and bias once for every sample in the training data. Please review section 1.2 to figure out the batch_size for stochastic gradient descent method.
#
# Again, the model will be trained for 200 epochs, and we split 20% of the data for validation.

# %%
modelSGD=tf.keras.models.load_model('initial_model')
modelSGD.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.SGD(learning_rate=0.1), metrics=['accuracy'])
start_time=time.time()
# start your code here
historySGD = modelSGD.fit(
    X, #please replace None by something meaningful
    y_one_hot, #please replace None by something meaningful
    validation_split=0.2, 
    epochs=200, 
    batch_size=1) #please replace None by something meaningful
# end your code here
print("Time taken: %.2fs" % (time.time() - start_time))
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9657 - accuracy: 0.5450 - val_loss: 0.9113 - val_accuracy: 0.4700
# Epoch 2/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9386 - accuracy: 0.5675 - val_loss: 0.6480 - val_accuracy: 0.6600
# Epoch 3/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8815 - accuracy: 0.5838 - val_loss: 0.8624 - val_accuracy: 0.6300
# Epoch 4/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9014 - accuracy: 0.5725 - val_loss: 0.9711 - val_accuracy: 0.4700
# Epoch 5/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9415 - accuracy: 0.5462 - val_loss: 0.9001 - val_accuracy: 0.5550
# Epoch 6/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9246 - accuracy: 0.5587 - val_loss: 0.9486 - val_accuracy: 0.5650
# Epoch 7/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0215 - accuracy: 0.5038 - val_loss: 0.8924 - val_accuracy: 0.5200
# Epoch 8/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9823 - accuracy: 0.5625 - val_loss: 1.1024 - val_accuracy: 0.5150
# Epoch 9/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8963 - accuracy: 0.6037 - val_loss: 0.9148 - val_accuracy: 0.5050
# Epoch 10/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9282 - accuracy: 0.5163 - val_loss: 0.8642 - val_accuracy: 0.5600
# Epoch 11/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9011 - accuracy: 0.5788 - val_loss: 0.8854 - val_accuracy: 0.5600
# Epoch 12/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9474 - accuracy: 0.5163 - val_loss: 0.8077 - val_accuracy: 0.6550
# Epoch 13/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0137 - accuracy: 0.4963 - val_loss: 1.0166 - val_accuracy: 0.4850
# Epoch 14/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9388 - accuracy: 0.5850 - val_loss: 0.6202 - val_accuracy: 0.7550
# Epoch 15/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8991 - accuracy: 0.6062 - val_loss: 0.9179 - val_accuracy: 0.5750
# Epoch 16/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9526 - accuracy: 0.5638 - val_loss: 1.2169 - val_accuracy: 0.6150
# Epoch 17/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9088 - accuracy: 0.6187 - val_loss: 0.5980 - val_accuracy: 0.7100
# Epoch 18/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9777 - accuracy: 0.5375 - val_loss: 0.9750 - val_accuracy: 0.5150
# Epoch 19/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9237 - accuracy: 0.5250 - val_loss: 0.9030 - val_accuracy: 0.4900
# Epoch 20/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9082 - accuracy: 0.5600 - val_loss: 0.7427 - val_accuracy: 0.7050
# Epoch 21/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8885 - accuracy: 0.5813 - val_loss: 1.0856 - val_accuracy: 0.7450
# Epoch 22/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9987 - accuracy: 0.5387 - val_loss: 1.0741 - val_accuracy: 0.5000
# Epoch 23/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9924 - accuracy: 0.5163 - val_loss: 0.9045 - val_accuracy: 0.6100
# Epoch 24/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9621 - accuracy: 0.5450 - val_loss: 0.9117 - val_accuracy: 0.5450
# Epoch 25/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9599 - accuracy: 0.5587 - val_loss: 0.7795 - val_accuracy: 0.6800
# Epoch 26/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9859 - accuracy: 0.4725 - val_loss: 0.8783 - val_accuracy: 0.5450
# Epoch 27/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9036 - accuracy: 0.5350 - val_loss: 0.9187 - val_accuracy: 0.5650
# Epoch 28/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8963 - accuracy: 0.6025 - val_loss: 0.7288 - val_accuracy: 0.6400
# Epoch 29/200
# 800/800 [==============================] - 2s 2ms/step - loss: 1.0110 - accuracy: 0.5350 - val_loss: 1.0015 - val_accuracy: 0.5400
# Epoch 30/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9009 - accuracy: 0.5950 - val_loss: 0.6633 - val_accuracy: 0.7250
# Epoch 31/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8951 - accuracy: 0.5838 - val_loss: 1.3944 - val_accuracy: 0.4600
# Epoch 32/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9633 - accuracy: 0.5725 - val_loss: 0.7417 - val_accuracy: 0.5350
# Epoch 33/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8515 - accuracy: 0.6175 - val_loss: 1.1055 - val_accuracy: 0.4900
# Epoch 34/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9432 - accuracy: 0.5288 - val_loss: 0.9339 - val_accuracy: 0.5050
# Epoch 35/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9520 - accuracy: 0.5650 - val_loss: 0.8295 - val_accuracy: 0.6400
# Epoch 36/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8716 - accuracy: 0.5987 - val_loss: 0.8159 - val_accuracy: 0.6000
# Epoch 37/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9285 - accuracy: 0.5462 - val_loss: 0.8620 - val_accuracy: 0.5900
# Epoch 38/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0426 - accuracy: 0.5075 - val_loss: 0.9642 - val_accuracy: 0.4950
# Epoch 39/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9714 - accuracy: 0.4663 - val_loss: 0.9659 - val_accuracy: 0.4850
# Epoch 40/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0138 - accuracy: 0.5075 - val_loss: 0.9531 - val_accuracy: 0.4500
# Epoch 41/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9134 - accuracy: 0.5650 - val_loss: 0.8574 - val_accuracy: 0.6850
# Epoch 42/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9424 - accuracy: 0.5525 - val_loss: 0.9343 - val_accuracy: 0.6400
# Epoch 43/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9406 - accuracy: 0.5813 - val_loss: 0.8737 - val_accuracy: 0.6450
# Epoch 44/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8898 - accuracy: 0.5975 - val_loss: 0.8983 - val_accuracy: 0.5700
# Epoch 45/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8783 - accuracy: 0.5763 - val_loss: 1.0005 - val_accuracy: 0.5050
# Epoch 46/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9260 - accuracy: 0.5638 - val_loss: 1.1013 - val_accuracy: 0.5000
# Epoch 47/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9053 - accuracy: 0.5575 - val_loss: 0.9305 - val_accuracy: 0.4850
# Epoch 48/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9297 - accuracy: 0.5863 - val_loss: 0.7521 - val_accuracy: 0.7250
# Epoch 49/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0113 - accuracy: 0.5138 - val_loss: 0.8717 - val_accuracy: 0.6200
# Epoch 50/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9599 - accuracy: 0.5200 - val_loss: 0.9204 - val_accuracy: 0.4650
# Epoch 51/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9456 - accuracy: 0.5400 - val_loss: 0.8617 - val_accuracy: 0.5750
# Epoch 52/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0101 - accuracy: 0.5175 - val_loss: 0.9566 - val_accuracy: 0.4750
# Epoch 53/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8770 - accuracy: 0.5700 - val_loss: 0.7846 - val_accuracy: 0.6750
# Epoch 54/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9643 - accuracy: 0.5325 - val_loss: 0.9745 - val_accuracy: 0.4500
# Epoch 55/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8782 - accuracy: 0.5638 - val_loss: 1.0752 - val_accuracy: 0.4600
# Epoch 56/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9574 - accuracy: 0.5650 - val_loss: 1.0192 - val_accuracy: 0.6250
# Epoch 57/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.8911 - accuracy: 0.5950 - val_loss: 0.9724 - val_accuracy: 0.5600
# Epoch 58/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9311 - accuracy: 0.5825 - val_loss: 0.8860 - val_accuracy: 0.6450
# Epoch 59/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8594 - accuracy: 0.6212 - val_loss: 0.7490 - val_accuracy: 0.6300
# Epoch 60/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8898 - accuracy: 0.6012 - val_loss: 0.8770 - val_accuracy: 0.4950
# Epoch 61/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9226 - accuracy: 0.5550 - val_loss: 0.8344 - val_accuracy: 0.6750
# Epoch 62/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9613 - accuracy: 0.5725 - val_loss: 0.8329 - val_accuracy: 0.6950
# Epoch 63/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.8796 - accuracy: 0.5925 - val_loss: 0.8834 - val_accuracy: 0.5800
# Epoch 64/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8645 - accuracy: 0.6000 - val_loss: 0.7845 - val_accuracy: 0.6500
# Epoch 65/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9921 - accuracy: 0.4925 - val_loss: 1.0396 - val_accuracy: 0.4650
# Epoch 66/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9227 - accuracy: 0.5437 - val_loss: 1.0496 - val_accuracy: 0.5100
# Epoch 67/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9177 - accuracy: 0.5900 - val_loss: 0.6520 - val_accuracy: 0.7300
# Epoch 68/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9439 - accuracy: 0.5525 - val_loss: 0.9477 - val_accuracy: 0.5100
# Epoch 69/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8589 - accuracy: 0.5863 - val_loss: 1.0013 - val_accuracy: 0.4700
# Epoch 70/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9434 - accuracy: 0.5688 - val_loss: 0.9485 - val_accuracy: 0.5650
# Epoch 71/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8514 - accuracy: 0.6275 - val_loss: 1.2447 - val_accuracy: 0.6600
# Epoch 72/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9103 - accuracy: 0.5612 - val_loss: 0.9891 - val_accuracy: 0.5850
# Epoch 73/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9400 - accuracy: 0.5275 - val_loss: 0.7972 - val_accuracy: 0.6800
# Epoch 74/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8638 - accuracy: 0.5838 - val_loss: 0.9538 - val_accuracy: 0.5250
# Epoch 75/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9906 - accuracy: 0.5138 - val_loss: 1.0136 - val_accuracy: 0.6300
# Epoch 76/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9364 - accuracy: 0.5650 - val_loss: 0.9313 - val_accuracy: 0.5250
# Epoch 77/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9368 - accuracy: 0.5400 - val_loss: 0.9528 - val_accuracy: 0.5550
# Epoch 78/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9800 - accuracy: 0.5425 - val_loss: 0.9439 - val_accuracy: 0.5800
# Epoch 79/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9685 - accuracy: 0.5312 - val_loss: 0.9268 - val_accuracy: 0.4650
# Epoch 80/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9263 - accuracy: 0.5525 - val_loss: 0.7254 - val_accuracy: 0.6700
# Epoch 81/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0563 - accuracy: 0.4775 - val_loss: 0.9480 - val_accuracy: 0.4850
# Epoch 82/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9612 - accuracy: 0.4938 - val_loss: 0.9887 - val_accuracy: 0.5050
# Epoch 83/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9287 - accuracy: 0.5975 - val_loss: 0.6604 - val_accuracy: 0.6900
# Epoch 84/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8762 - accuracy: 0.6000 - val_loss: 0.8587 - val_accuracy: 0.6350
# Epoch 85/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9491 - accuracy: 0.5688 - val_loss: 0.9133 - val_accuracy: 0.6000
# Epoch 86/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8939 - accuracy: 0.5788 - val_loss: 0.9434 - val_accuracy: 0.6850
# Epoch 87/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9207 - accuracy: 0.5537 - val_loss: 0.9786 - val_accuracy: 0.5350
# Epoch 88/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9467 - accuracy: 0.5450 - val_loss: 0.9236 - val_accuracy: 0.5700
# Epoch 89/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9860 - accuracy: 0.5013 - val_loss: 1.0038 - val_accuracy: 0.5450
# Epoch 90/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9457 - accuracy: 0.5238 - val_loss: 0.9489 - val_accuracy: 0.5600
# Epoch 91/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9030 - accuracy: 0.5612 - val_loss: 0.8889 - val_accuracy: 0.5300
# Epoch 92/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8779 - accuracy: 0.5775 - val_loss: 0.9885 - val_accuracy: 0.4950
# Epoch 93/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9508 - accuracy: 0.4600 - val_loss: 0.8885 - val_accuracy: 0.4900
# Epoch 94/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9190 - accuracy: 0.5387 - val_loss: 0.7696 - val_accuracy: 0.6550
# Epoch 95/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8802 - accuracy: 0.5925 - val_loss: 0.6480 - val_accuracy: 0.7750
# Epoch 96/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9349 - accuracy: 0.5525 - val_loss: 0.9215 - val_accuracy: 0.5550
# Epoch 97/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8959 - accuracy: 0.5638 - val_loss: 0.5425 - val_accuracy: 0.7950
# Epoch 98/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8715 - accuracy: 0.6162 - val_loss: 1.0384 - val_accuracy: 0.4500
# Epoch 99/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9529 - accuracy: 0.5375 - val_loss: 0.9807 - val_accuracy: 0.6100
# Epoch 100/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9505 - accuracy: 0.5175 - val_loss: 0.9667 - val_accuracy: 0.5150
# Epoch 101/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9738 - accuracy: 0.5088 - val_loss: 0.9427 - val_accuracy: 0.5450
# Epoch 102/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8801 - accuracy: 0.5462 - val_loss: 0.9308 - val_accuracy: 0.5400
# Epoch 103/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9574 - accuracy: 0.5250 - val_loss: 0.9398 - val_accuracy: 0.5150
# Epoch 104/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9255 - accuracy: 0.5512 - val_loss: 0.8959 - val_accuracy: 0.5550
# Epoch 105/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9183 - accuracy: 0.5775 - val_loss: 0.8740 - val_accuracy: 0.6600
# Epoch 106/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9048 - accuracy: 0.6112 - val_loss: 1.2293 - val_accuracy: 0.6950
# Epoch 107/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8366 - accuracy: 0.6250 - val_loss: 0.7413 - val_accuracy: 0.5150
# Epoch 108/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9030 - accuracy: 0.5625 - val_loss: 0.9523 - val_accuracy: 0.5500
# Epoch 109/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8658 - accuracy: 0.6087 - val_loss: 0.8410 - val_accuracy: 0.6050
# Epoch 110/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9609 - accuracy: 0.5700 - val_loss: 1.2089 - val_accuracy: 0.4750
# Epoch 111/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8956 - accuracy: 0.6000 - val_loss: 1.0264 - val_accuracy: 0.5150
# Epoch 112/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9910 - accuracy: 0.5362 - val_loss: 0.9302 - val_accuracy: 0.5150
# Epoch 113/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9007 - accuracy: 0.5612 - val_loss: 1.0424 - val_accuracy: 0.5050
# Epoch 114/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9290 - accuracy: 0.5462 - val_loss: 1.0195 - val_accuracy: 0.4200
# Epoch 115/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8619 - accuracy: 0.5850 - val_loss: 0.6865 - val_accuracy: 0.7750
# Epoch 116/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9290 - accuracy: 0.5688 - val_loss: 0.8605 - val_accuracy: 0.4800
# Epoch 117/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8755 - accuracy: 0.6137 - val_loss: 1.0124 - val_accuracy: 0.5450
# Epoch 118/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8750 - accuracy: 0.5975 - val_loss: 0.9680 - val_accuracy: 0.6600
# Epoch 119/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9570 - accuracy: 0.5125 - val_loss: 1.0412 - val_accuracy: 0.4700
# Epoch 120/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9591 - accuracy: 0.5263 - val_loss: 0.9907 - val_accuracy: 0.5350
# Epoch 121/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9317 - accuracy: 0.5763 - val_loss: 0.9328 - val_accuracy: 0.4750
# Epoch 122/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9691 - accuracy: 0.5763 - val_loss: 0.6713 - val_accuracy: 0.6450
# Epoch 123/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.8753 - accuracy: 0.5688 - val_loss: 0.9622 - val_accuracy: 0.4650
# Epoch 124/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9423 - accuracy: 0.5163 - val_loss: 0.8043 - val_accuracy: 0.5850
# Epoch 125/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9001 - accuracy: 0.5763 - val_loss: 1.1505 - val_accuracy: 0.4000
# Epoch 126/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9108 - accuracy: 0.5375 - val_loss: 1.2101 - val_accuracy: 0.4650
# Epoch 127/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8997 - accuracy: 0.5763 - val_loss: 0.8452 - val_accuracy: 0.7300
# Epoch 128/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8374 - accuracy: 0.6187 - val_loss: 0.9418 - val_accuracy: 0.5050
# Epoch 129/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9643 - accuracy: 0.5375 - val_loss: 0.8580 - val_accuracy: 0.6050
# Epoch 130/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8482 - accuracy: 0.5975 - val_loss: 0.9232 - val_accuracy: 0.5500
# Epoch 131/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9229 - accuracy: 0.5525 - val_loss: 0.9654 - val_accuracy: 0.5350
# Epoch 132/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9042 - accuracy: 0.5738 - val_loss: 0.6703 - val_accuracy: 0.7050
# Epoch 133/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9956 - accuracy: 0.5275 - val_loss: 1.1210 - val_accuracy: 0.4100
# Epoch 134/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9011 - accuracy: 0.5387 - val_loss: 0.8886 - val_accuracy: 0.4500
# Epoch 135/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9042 - accuracy: 0.5750 - val_loss: 1.1251 - val_accuracy: 0.5750
# Epoch 136/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9539 - accuracy: 0.5000 - val_loss: 1.0887 - val_accuracy: 0.4800
# Epoch 137/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9289 - accuracy: 0.5300 - val_loss: 0.9595 - val_accuracy: 0.4700
# Epoch 138/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8927 - accuracy: 0.5638 - val_loss: 0.9176 - val_accuracy: 0.5900
# Epoch 139/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9338 - accuracy: 0.5487 - val_loss: 1.0277 - val_accuracy: 0.4850
# Epoch 140/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9309 - accuracy: 0.5612 - val_loss: 0.8330 - val_accuracy: 0.6250
# Epoch 141/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0125 - accuracy: 0.4812 - val_loss: 0.9311 - val_accuracy: 0.5150
# Epoch 142/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9386 - accuracy: 0.4900 - val_loss: 0.7862 - val_accuracy: 0.6650
# Epoch 143/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9054 - accuracy: 0.5400 - val_loss: 0.8588 - val_accuracy: 0.5300
# Epoch 144/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8441 - accuracy: 0.6037 - val_loss: 1.2201 - val_accuracy: 0.6100
# Epoch 145/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9746 - accuracy: 0.5200 - val_loss: 0.9315 - val_accuracy: 0.5150
# Epoch 146/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0000 - accuracy: 0.5175 - val_loss: 0.9470 - val_accuracy: 0.4700
# Epoch 147/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8994 - accuracy: 0.5412 - val_loss: 0.9688 - val_accuracy: 0.4200
# Epoch 148/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9007 - accuracy: 0.5487 - val_loss: 0.7957 - val_accuracy: 0.6000
# Epoch 149/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8672 - accuracy: 0.5813 - val_loss: 1.0932 - val_accuracy: 0.5250
# Epoch 150/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9741 - accuracy: 0.5188 - val_loss: 0.9983 - val_accuracy: 0.5200
# Epoch 151/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9297 - accuracy: 0.5100 - val_loss: 0.9513 - val_accuracy: 0.5450
# Epoch 152/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9663 - accuracy: 0.5462 - val_loss: 1.0171 - val_accuracy: 0.5100
# Epoch 153/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9460 - accuracy: 0.5275 - val_loss: 0.8189 - val_accuracy: 0.6650
# Epoch 154/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9080 - accuracy: 0.5763 - val_loss: 0.9984 - val_accuracy: 0.4600
# Epoch 155/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0038 - accuracy: 0.4850 - val_loss: 0.9070 - val_accuracy: 0.5150
# Epoch 156/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0113 - accuracy: 0.4888 - val_loss: 0.9707 - val_accuracy: 0.5400
# Epoch 157/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.8950 - accuracy: 0.5750 - val_loss: 0.9642 - val_accuracy: 0.5850
# Epoch 158/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.8584 - accuracy: 0.5825 - val_loss: 0.9714 - val_accuracy: 0.4850
# Epoch 159/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9834 - accuracy: 0.4700 - val_loss: 0.9774 - val_accuracy: 0.5300
# Epoch 160/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9421 - accuracy: 0.5100 - val_loss: 1.0142 - val_accuracy: 0.5200
# Epoch 161/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9122 - accuracy: 0.5275 - val_loss: 1.0117 - val_accuracy: 0.5250
# Epoch 162/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8850 - accuracy: 0.5625 - val_loss: 0.9873 - val_accuracy: 0.5650
# Epoch 163/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9787 - accuracy: 0.5238 - val_loss: 1.0495 - val_accuracy: 0.4550
# Epoch 164/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9706 - accuracy: 0.5013 - val_loss: 0.9513 - val_accuracy: 0.5200
# Epoch 165/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0023 - accuracy: 0.4663 - val_loss: 1.0270 - val_accuracy: 0.5350
# Epoch 166/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9999 - accuracy: 0.5150 - val_loss: 1.0147 - val_accuracy: 0.4650
# Epoch 167/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9296 - accuracy: 0.5300 - val_loss: 1.0651 - val_accuracy: 0.6050
# Epoch 168/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9872 - accuracy: 0.4812 - val_loss: 1.0295 - val_accuracy: 0.4250
# Epoch 169/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9266 - accuracy: 0.5462 - val_loss: 1.1649 - val_accuracy: 0.6300
# Epoch 170/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9286 - accuracy: 0.5612 - val_loss: 0.9766 - val_accuracy: 0.4900
# Epoch 171/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9373 - accuracy: 0.4900 - val_loss: 0.9806 - val_accuracy: 0.6300
# Epoch 172/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9097 - accuracy: 0.5562 - val_loss: 0.9188 - val_accuracy: 0.4650
# Epoch 173/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.8494 - accuracy: 0.6012 - val_loss: 0.6908 - val_accuracy: 0.7600
# Epoch 174/200
# 800/800 [==============================] - 1s 2ms/step - loss: 1.0120 - accuracy: 0.5125 - val_loss: 0.9861 - val_accuracy: 0.5150
# Epoch 175/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9589 - accuracy: 0.5213 - val_loss: 0.9215 - val_accuracy: 0.5400
# Epoch 176/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8993 - accuracy: 0.5738 - val_loss: 1.1501 - val_accuracy: 0.5200
# Epoch 177/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9402 - accuracy: 0.5400 - val_loss: 0.9814 - val_accuracy: 0.6500
# Epoch 178/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9393 - accuracy: 0.5412 - val_loss: 1.1145 - val_accuracy: 0.5400
# Epoch 179/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9275 - accuracy: 0.5500 - val_loss: 0.9169 - val_accuracy: 0.6000
# Epoch 180/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9277 - accuracy: 0.5375 - val_loss: 1.0546 - val_accuracy: 0.5600
# Epoch 181/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9158 - accuracy: 0.5450 - val_loss: 0.9344 - val_accuracy: 0.5250
# Epoch 182/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.8904 - accuracy: 0.5975 - val_loss: 0.9535 - val_accuracy: 0.4700
# Epoch 183/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.9284 - accuracy: 0.5562 - val_loss: 0.9555 - val_accuracy: 0.5900
# Epoch 184/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8955 - accuracy: 0.5475 - val_loss: 1.0555 - val_accuracy: 0.4150
# Epoch 185/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9277 - accuracy: 0.5738 - val_loss: 1.0721 - val_accuracy: 0.4050
# Epoch 186/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9848 - accuracy: 0.4812 - val_loss: 1.0053 - val_accuracy: 0.4700
# Epoch 187/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9801 - accuracy: 0.5238 - val_loss: 0.8145 - val_accuracy: 0.6250
# Epoch 188/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9294 - accuracy: 0.5425 - val_loss: 0.7413 - val_accuracy: 0.7250
# Epoch 189/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.8897 - accuracy: 0.5863 - val_loss: 1.5372 - val_accuracy: 0.5650
# Epoch 190/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8966 - accuracy: 0.5888 - val_loss: 0.9695 - val_accuracy: 0.4700
# Epoch 191/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8962 - accuracy: 0.5525 - val_loss: 0.9916 - val_accuracy: 0.5850
# Epoch 192/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9090 - accuracy: 0.5587 - val_loss: 0.9885 - val_accuracy: 0.5200
# Epoch 193/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9589 - accuracy: 0.5550 - val_loss: 0.8809 - val_accuracy: 0.6600
# Epoch 194/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9434 - accuracy: 0.5625 - val_loss: 0.9436 - val_accuracy: 0.5200
# Epoch 195/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9348 - accuracy: 0.5175 - val_loss: 0.9854 - val_accuracy: 0.5200
# Epoch 196/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9289 - accuracy: 0.5362 - val_loss: 1.0038 - val_accuracy: 0.5550
# Epoch 197/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9308 - accuracy: 0.5612 - val_loss: 0.8756 - val_accuracy: 0.6100
# Epoch 198/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.8559 - accuracy: 0.5987 - val_loss: 0.9592 - val_accuracy: 0.4800
# Epoch 199/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9316 - accuracy: 0.5775 - val_loss: 0.8042 - val_accuracy: 0.6950
# Epoch 200/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9068 - accuracy: 0.5825 - val_loss: 0.8097 - val_accuracy: 0.7350
# Time taken: 285.25s

# %% [markdown]
# Expected output for the first 3 epochs:
# ```
# Epoch 1/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.8803 - accuracy: 0.5938 - val_loss: 1.3032 - val_accuracy: 0.5000
# Epoch 2/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9080 - accuracy: 0.5562 - val_loss: 1.0528 - val_accuracy: 0.4600
# Epoch 3/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.9684 - accuracy: 0.5688 - val_loss: 0.8736 - val_accuracy: 0.5950
# ...
# Time taken: 382.39s
# ```
# It's OK that you have different values in loss, accuracy, val_loss, and val_accuracy. But you should have `800/800 [==============================]` for every epoch. It indicates that you have `800` epochs for every epoch, which is the number of samples in the training data. Your 'Time taken' should be similar to ours without using any accerlerating device (GPU or TPU).
#
# The final accuracy and val_accuracy should be greater than `0.4`.
#
# Let's print the training history out.

# %%
# plot training history
pyplot.plot(historySGD.history['accuracy'], label='train')
pyplot.plot(historySGD.history['val_accuracy'], label='validation')
pyplot.xlabel('epoch number')
pyplot.ylabel('accuracy')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ### 2.5 Compiling and fitting neural network using mini-batch gradient descent
# We will reload the untrained model again and train it using mini-batch gradient descent method. Let batch_size=32, and see how training process looks like
#
# Again, the model will be trained for 200 epochs, and we split 20% of the data for validation.

# %%
model32=tf.keras.models.load_model('initial_model')
model32.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.SGD(learning_rate=0.1), metrics=['accuracy'])
start_time=time.time()
# start your code here
history32 = model32.fit(
    X, #please replace None by something meaningful
    y_one_hot, #please replace None by something meaningful
    validation_split=0.2, 
    epochs=200, 
    batch_size=32) #please replace None by something meaningful
# end your code here
print("Time taken: %.2fs" % (time.time() - start_time))
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/200
# 25/25 [==============================] - 1s 9ms/step - loss: 0.7829 - accuracy: 0.6275 - val_loss: 0.5810 - val_accuracy: 0.7750
# Epoch 2/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6249 - accuracy: 0.7250 - val_loss: 0.5702 - val_accuracy: 0.8250
# Epoch 3/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5769 - accuracy: 0.7563 - val_loss: 0.4895 - val_accuracy: 0.8300
# Epoch 4/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5372 - accuracy: 0.7862 - val_loss: 0.4894 - val_accuracy: 0.8350
# Epoch 5/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5271 - accuracy: 0.7775 - val_loss: 0.4565 - val_accuracy: 0.7850
# Epoch 6/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5048 - accuracy: 0.7912 - val_loss: 0.4183 - val_accuracy: 0.8200
# Epoch 7/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5038 - accuracy: 0.7900 - val_loss: 0.4595 - val_accuracy: 0.8150
# Epoch 8/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5034 - accuracy: 0.7950 - val_loss: 0.3992 - val_accuracy: 0.8350
# Epoch 9/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4794 - accuracy: 0.8125 - val_loss: 0.4007 - val_accuracy: 0.8400
# Epoch 10/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4693 - accuracy: 0.8125 - val_loss: 0.3835 - val_accuracy: 0.8300
# Epoch 11/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4619 - accuracy: 0.8200 - val_loss: 0.3876 - val_accuracy: 0.8450
# Epoch 12/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4599 - accuracy: 0.8112 - val_loss: 0.4652 - val_accuracy: 0.8050
# Epoch 13/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4496 - accuracy: 0.8112 - val_loss: 0.3807 - val_accuracy: 0.8400
# Epoch 14/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4442 - accuracy: 0.8188 - val_loss: 0.3817 - val_accuracy: 0.8400
# Epoch 15/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4644 - accuracy: 0.7987 - val_loss: 0.3858 - val_accuracy: 0.8450
# Epoch 16/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4347 - accuracy: 0.8150 - val_loss: 0.3970 - val_accuracy: 0.8300
# Epoch 17/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4286 - accuracy: 0.8300 - val_loss: 0.3597 - val_accuracy: 0.8650
# Epoch 18/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4279 - accuracy: 0.8238 - val_loss: 0.3895 - val_accuracy: 0.8350
# Epoch 19/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4406 - accuracy: 0.8200 - val_loss: 0.3873 - val_accuracy: 0.8250
# Epoch 20/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4578 - accuracy: 0.8175 - val_loss: 0.3587 - val_accuracy: 0.8450
# Epoch 21/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4266 - accuracy: 0.8238 - val_loss: 0.3990 - val_accuracy: 0.8150
# Epoch 22/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4208 - accuracy: 0.8300 - val_loss: 0.3669 - val_accuracy: 0.8400
# Epoch 23/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4239 - accuracy: 0.8213 - val_loss: 0.3561 - val_accuracy: 0.8350
# Epoch 24/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4434 - accuracy: 0.7987 - val_loss: 0.3674 - val_accuracy: 0.8400
# Epoch 25/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.8188 - val_loss: 0.3612 - val_accuracy: 0.8450
# Epoch 26/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4294 - accuracy: 0.8350 - val_loss: 0.3520 - val_accuracy: 0.8400
# Epoch 27/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4257 - accuracy: 0.8213 - val_loss: 0.3708 - val_accuracy: 0.8400
# Epoch 28/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4223 - accuracy: 0.8213 - val_loss: 0.3832 - val_accuracy: 0.8300
# Epoch 29/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4203 - accuracy: 0.8263 - val_loss: 0.4224 - val_accuracy: 0.8150
# Epoch 30/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4247 - accuracy: 0.8300 - val_loss: 0.3572 - val_accuracy: 0.8400
# Epoch 31/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4195 - accuracy: 0.8288 - val_loss: 0.3755 - val_accuracy: 0.8450
# Epoch 32/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4168 - accuracy: 0.8288 - val_loss: 0.4149 - val_accuracy: 0.8150
# Epoch 33/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4206 - accuracy: 0.8200 - val_loss: 0.4912 - val_accuracy: 0.7600
# Epoch 34/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4397 - accuracy: 0.8175 - val_loss: 0.3518 - val_accuracy: 0.8450
# Epoch 35/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4199 - accuracy: 0.8250 - val_loss: 0.4515 - val_accuracy: 0.8150
# Epoch 36/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4334 - accuracy: 0.8188 - val_loss: 0.4068 - val_accuracy: 0.8150
# Epoch 37/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4268 - accuracy: 0.8175 - val_loss: 0.3563 - val_accuracy: 0.8450
# Epoch 38/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4284 - accuracy: 0.8112 - val_loss: 0.3587 - val_accuracy: 0.8450
# Epoch 39/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4215 - accuracy: 0.8288 - val_loss: 0.3954 - val_accuracy: 0.8250
# Epoch 40/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4274 - accuracy: 0.8112 - val_loss: 0.4127 - val_accuracy: 0.8150
# Epoch 41/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4302 - accuracy: 0.8175 - val_loss: 0.3610 - val_accuracy: 0.8450
# Epoch 42/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4183 - accuracy: 0.8163 - val_loss: 0.3728 - val_accuracy: 0.8350
# Epoch 43/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4181 - accuracy: 0.8188 - val_loss: 0.5610 - val_accuracy: 0.7200
# Epoch 44/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4353 - accuracy: 0.8200 - val_loss: 0.3634 - val_accuracy: 0.8450
# Epoch 45/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4173 - accuracy: 0.8263 - val_loss: 0.3534 - val_accuracy: 0.8450
# Epoch 46/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4164 - accuracy: 0.8213 - val_loss: 0.3709 - val_accuracy: 0.8350
# Epoch 47/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4230 - accuracy: 0.8238 - val_loss: 0.3997 - val_accuracy: 0.8150
# Epoch 48/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.8238 - val_loss: 0.3511 - val_accuracy: 0.8400
# Epoch 49/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4191 - accuracy: 0.8213 - val_loss: 0.3673 - val_accuracy: 0.8400
# Epoch 50/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4164 - accuracy: 0.8263 - val_loss: 0.3684 - val_accuracy: 0.8350
# Epoch 51/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4182 - accuracy: 0.8238 - val_loss: 0.3536 - val_accuracy: 0.8450
# Epoch 52/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4328 - accuracy: 0.8163 - val_loss: 0.3984 - val_accuracy: 0.8300
# Epoch 53/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4180 - accuracy: 0.8188 - val_loss: 0.3861 - val_accuracy: 0.8250
# Epoch 54/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4242 - accuracy: 0.8213 - val_loss: 0.4047 - val_accuracy: 0.8150
# Epoch 55/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8325 - val_loss: 0.3591 - val_accuracy: 0.8500
# Epoch 56/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4127 - accuracy: 0.8300 - val_loss: 0.3628 - val_accuracy: 0.8450
# Epoch 57/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4131 - accuracy: 0.8350 - val_loss: 0.3751 - val_accuracy: 0.8300
# Epoch 58/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4168 - accuracy: 0.8200 - val_loss: 0.3779 - val_accuracy: 0.8300
# Epoch 59/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4088 - accuracy: 0.8275 - val_loss: 0.3502 - val_accuracy: 0.8400
# Epoch 60/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4153 - accuracy: 0.8275 - val_loss: 0.4204 - val_accuracy: 0.8150
# Epoch 61/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4212 - accuracy: 0.8112 - val_loss: 0.4218 - val_accuracy: 0.8150
# Epoch 62/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4093 - accuracy: 0.8325 - val_loss: 0.3576 - val_accuracy: 0.8500
# Epoch 63/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4129 - accuracy: 0.8213 - val_loss: 0.3656 - val_accuracy: 0.8350
# Epoch 64/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4142 - accuracy: 0.8313 - val_loss: 0.3874 - val_accuracy: 0.8250
# Epoch 65/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4150 - accuracy: 0.8175 - val_loss: 0.3583 - val_accuracy: 0.8450
# Epoch 66/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4170 - accuracy: 0.8288 - val_loss: 0.3573 - val_accuracy: 0.8400
# Epoch 67/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4147 - accuracy: 0.8175 - val_loss: 0.3611 - val_accuracy: 0.8400
# Epoch 68/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4102 - accuracy: 0.8275 - val_loss: 0.3716 - val_accuracy: 0.8350
# Epoch 69/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4199 - accuracy: 0.8200 - val_loss: 0.4030 - val_accuracy: 0.8250
# Epoch 70/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4141 - accuracy: 0.8263 - val_loss: 0.3608 - val_accuracy: 0.8500
# Epoch 71/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4174 - accuracy: 0.8213 - val_loss: 0.3655 - val_accuracy: 0.8350
# Epoch 72/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4213 - accuracy: 0.8238 - val_loss: 0.3871 - val_accuracy: 0.8200
# Epoch 73/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4219 - accuracy: 0.8225 - val_loss: 0.4261 - val_accuracy: 0.8250
# Epoch 74/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4142 - accuracy: 0.8213 - val_loss: 0.3534 - val_accuracy: 0.8500
# Epoch 75/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4165 - accuracy: 0.8238 - val_loss: 0.3556 - val_accuracy: 0.8400
# Epoch 76/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4164 - accuracy: 0.8263 - val_loss: 0.3570 - val_accuracy: 0.8500
# Epoch 77/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4108 - accuracy: 0.8288 - val_loss: 0.3618 - val_accuracy: 0.8450
# Epoch 78/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.8225 - val_loss: 0.3542 - val_accuracy: 0.8450
# Epoch 79/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4137 - accuracy: 0.8300 - val_loss: 0.3649 - val_accuracy: 0.8400
# Epoch 80/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4148 - accuracy: 0.8250 - val_loss: 0.3979 - val_accuracy: 0.8150
# Epoch 81/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4143 - accuracy: 0.8338 - val_loss: 0.3622 - val_accuracy: 0.8550
# Epoch 82/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4148 - accuracy: 0.8238 - val_loss: 0.3801 - val_accuracy: 0.8350
# Epoch 83/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4131 - accuracy: 0.8200 - val_loss: 0.3528 - val_accuracy: 0.8500
# Epoch 84/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4132 - accuracy: 0.8263 - val_loss: 0.3763 - val_accuracy: 0.8400
# Epoch 85/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4127 - accuracy: 0.8263 - val_loss: 0.3817 - val_accuracy: 0.8350
# Epoch 86/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4111 - accuracy: 0.8288 - val_loss: 0.3659 - val_accuracy: 0.8400
# Epoch 87/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4068 - accuracy: 0.8238 - val_loss: 0.3503 - val_accuracy: 0.8500
# Epoch 88/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4188 - accuracy: 0.8163 - val_loss: 0.3694 - val_accuracy: 0.8350
# Epoch 89/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4115 - accuracy: 0.8313 - val_loss: 0.3578 - val_accuracy: 0.8450
# Epoch 90/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4113 - accuracy: 0.8300 - val_loss: 0.3536 - val_accuracy: 0.8500
# Epoch 91/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4144 - accuracy: 0.8138 - val_loss: 0.3893 - val_accuracy: 0.8200
# Epoch 92/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4087 - accuracy: 0.8363 - val_loss: 0.3530 - val_accuracy: 0.8450
# Epoch 93/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4174 - accuracy: 0.8163 - val_loss: 0.3620 - val_accuracy: 0.8350
# Epoch 94/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4138 - accuracy: 0.8150 - val_loss: 0.3751 - val_accuracy: 0.8300
# Epoch 95/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4078 - accuracy: 0.8263 - val_loss: 0.3477 - val_accuracy: 0.8500
# Epoch 96/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4178 - accuracy: 0.8238 - val_loss: 0.3695 - val_accuracy: 0.8400
# Epoch 97/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4108 - accuracy: 0.8338 - val_loss: 0.3955 - val_accuracy: 0.8250
# Epoch 98/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4102 - accuracy: 0.8188 - val_loss: 0.4094 - val_accuracy: 0.8150
# Epoch 99/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4186 - accuracy: 0.8288 - val_loss: 0.3804 - val_accuracy: 0.8400
# Epoch 100/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4089 - accuracy: 0.8238 - val_loss: 0.3715 - val_accuracy: 0.8500
# Epoch 101/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4062 - accuracy: 0.8250 - val_loss: 0.3529 - val_accuracy: 0.8500
# Epoch 102/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4114 - accuracy: 0.8250 - val_loss: 0.4060 - val_accuracy: 0.8150
# Epoch 103/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4148 - accuracy: 0.8250 - val_loss: 0.3493 - val_accuracy: 0.8450
# Epoch 104/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4071 - accuracy: 0.8313 - val_loss: 0.3618 - val_accuracy: 0.8400
# Epoch 105/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4166 - accuracy: 0.8150 - val_loss: 0.3645 - val_accuracy: 0.8400
# Epoch 106/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4098 - accuracy: 0.8225 - val_loss: 0.3602 - val_accuracy: 0.8400
# Epoch 107/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4059 - accuracy: 0.8275 - val_loss: 0.3642 - val_accuracy: 0.8400
# Epoch 108/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4056 - accuracy: 0.8288 - val_loss: 0.3549 - val_accuracy: 0.8500
# Epoch 109/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4050 - accuracy: 0.8288 - val_loss: 0.3531 - val_accuracy: 0.8400
# Epoch 110/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4170 - accuracy: 0.8238 - val_loss: 0.3556 - val_accuracy: 0.8450
# Epoch 111/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4087 - accuracy: 0.8263 - val_loss: 0.3876 - val_accuracy: 0.8250
# Epoch 112/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4149 - accuracy: 0.8200 - val_loss: 0.3945 - val_accuracy: 0.8150
# Epoch 113/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4129 - accuracy: 0.8225 - val_loss: 0.4091 - val_accuracy: 0.8150
# Epoch 114/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4096 - accuracy: 0.8325 - val_loss: 0.3803 - val_accuracy: 0.8400
# Epoch 115/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4128 - accuracy: 0.8225 - val_loss: 0.3587 - val_accuracy: 0.8450
# Epoch 116/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4147 - accuracy: 0.8313 - val_loss: 0.3818 - val_accuracy: 0.8250
# Epoch 117/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.8300 - val_loss: 0.3944 - val_accuracy: 0.8200
# Epoch 118/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4084 - accuracy: 0.8288 - val_loss: 0.3764 - val_accuracy: 0.8400
# Epoch 119/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4137 - accuracy: 0.8200 - val_loss: 0.3799 - val_accuracy: 0.8350
# Epoch 120/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4071 - accuracy: 0.8288 - val_loss: 0.4012 - val_accuracy: 0.8300
# Epoch 121/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4123 - accuracy: 0.8300 - val_loss: 0.3720 - val_accuracy: 0.8350
# Epoch 122/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4103 - accuracy: 0.8225 - val_loss: 0.3578 - val_accuracy: 0.8500
# Epoch 123/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4093 - accuracy: 0.8250 - val_loss: 0.4135 - val_accuracy: 0.8200
# Epoch 124/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4149 - accuracy: 0.8225 - val_loss: 0.3537 - val_accuracy: 0.8450
# Epoch 125/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4100 - accuracy: 0.8288 - val_loss: 0.3460 - val_accuracy: 0.8500
# Epoch 126/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4138 - accuracy: 0.8275 - val_loss: 0.3534 - val_accuracy: 0.8450
# Epoch 127/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4081 - accuracy: 0.8125 - val_loss: 0.4063 - val_accuracy: 0.8200
# Epoch 128/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4127 - accuracy: 0.8175 - val_loss: 0.3616 - val_accuracy: 0.8400
# Epoch 129/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4152 - accuracy: 0.8175 - val_loss: 0.3870 - val_accuracy: 0.8400
# Epoch 130/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4130 - accuracy: 0.8263 - val_loss: 0.3525 - val_accuracy: 0.8500
# Epoch 131/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4154 - accuracy: 0.8275 - val_loss: 0.3590 - val_accuracy: 0.8500
# Epoch 132/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4196 - accuracy: 0.8250 - val_loss: 0.3692 - val_accuracy: 0.8500
# Epoch 133/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4083 - accuracy: 0.8263 - val_loss: 0.3812 - val_accuracy: 0.8350
# Epoch 134/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4100 - accuracy: 0.8250 - val_loss: 0.3525 - val_accuracy: 0.8550
# Epoch 135/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4120 - accuracy: 0.8263 - val_loss: 0.3575 - val_accuracy: 0.8500
# Epoch 136/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4076 - accuracy: 0.8263 - val_loss: 0.4279 - val_accuracy: 0.8200
# Epoch 137/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4054 - accuracy: 0.8300 - val_loss: 0.3585 - val_accuracy: 0.8450
# Epoch 138/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4208 - accuracy: 0.8188 - val_loss: 0.3497 - val_accuracy: 0.8550
# Epoch 139/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4154 - accuracy: 0.8263 - val_loss: 0.3778 - val_accuracy: 0.8250
# Epoch 140/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4090 - accuracy: 0.8313 - val_loss: 0.3885 - val_accuracy: 0.8400
# Epoch 141/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4091 - accuracy: 0.8275 - val_loss: 0.3660 - val_accuracy: 0.8350
# Epoch 142/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4040 - accuracy: 0.8263 - val_loss: 0.3696 - val_accuracy: 0.8400
# Epoch 143/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4120 - accuracy: 0.8300 - val_loss: 0.3634 - val_accuracy: 0.8500
# Epoch 144/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4090 - accuracy: 0.8275 - val_loss: 0.3584 - val_accuracy: 0.8450
# Epoch 145/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4138 - accuracy: 0.8250 - val_loss: 0.3717 - val_accuracy: 0.8400
# Epoch 146/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4058 - accuracy: 0.8300 - val_loss: 0.3642 - val_accuracy: 0.8450
# Epoch 147/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4104 - accuracy: 0.8363 - val_loss: 0.3500 - val_accuracy: 0.8450
# Epoch 148/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4133 - accuracy: 0.8225 - val_loss: 0.3852 - val_accuracy: 0.8300
# Epoch 149/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4046 - accuracy: 0.8275 - val_loss: 0.3818 - val_accuracy: 0.8350
# Epoch 150/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4109 - accuracy: 0.8213 - val_loss: 0.3534 - val_accuracy: 0.8550
# Epoch 151/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4100 - accuracy: 0.8250 - val_loss: 0.3914 - val_accuracy: 0.8250
# Epoch 152/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4079 - accuracy: 0.8325 - val_loss: 0.3841 - val_accuracy: 0.8250
# Epoch 153/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8275 - val_loss: 0.3880 - val_accuracy: 0.8200
# Epoch 154/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4109 - accuracy: 0.8325 - val_loss: 0.4074 - val_accuracy: 0.8200
# Epoch 155/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4090 - accuracy: 0.8225 - val_loss: 0.4190 - val_accuracy: 0.8250
# Epoch 156/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4088 - accuracy: 0.8250 - val_loss: 0.3764 - val_accuracy: 0.8350
# Epoch 157/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4060 - accuracy: 0.8250 - val_loss: 0.3878 - val_accuracy: 0.8200
# Epoch 158/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4059 - accuracy: 0.8213 - val_loss: 0.3728 - val_accuracy: 0.8350
# Epoch 159/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4130 - accuracy: 0.8263 - val_loss: 0.3698 - val_accuracy: 0.8450
# Epoch 160/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4138 - accuracy: 0.8275 - val_loss: 0.3631 - val_accuracy: 0.8400
# Epoch 161/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4054 - accuracy: 0.8325 - val_loss: 0.3876 - val_accuracy: 0.8400
# Epoch 162/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4098 - accuracy: 0.8300 - val_loss: 0.3662 - val_accuracy: 0.8450
# Epoch 163/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4098 - accuracy: 0.8300 - val_loss: 0.3593 - val_accuracy: 0.8500
# Epoch 164/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4116 - accuracy: 0.8213 - val_loss: 0.3789 - val_accuracy: 0.8400
# Epoch 165/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4078 - accuracy: 0.8238 - val_loss: 0.3520 - val_accuracy: 0.8500
# Epoch 166/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4071 - accuracy: 0.8225 - val_loss: 0.3428 - val_accuracy: 0.8500
# Epoch 167/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4146 - accuracy: 0.8275 - val_loss: 0.3576 - val_accuracy: 0.8500
# Epoch 168/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.8313 - val_loss: 0.3978 - val_accuracy: 0.8200
# Epoch 169/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4108 - accuracy: 0.8188 - val_loss: 0.3958 - val_accuracy: 0.8350
# Epoch 170/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4104 - accuracy: 0.8275 - val_loss: 0.3584 - val_accuracy: 0.8600
# Epoch 171/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4101 - accuracy: 0.8238 - val_loss: 0.3692 - val_accuracy: 0.8400
# Epoch 172/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4055 - accuracy: 0.8350 - val_loss: 0.4329 - val_accuracy: 0.8200
# Epoch 173/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4060 - accuracy: 0.8300 - val_loss: 0.3795 - val_accuracy: 0.8300
# Epoch 174/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4113 - accuracy: 0.8175 - val_loss: 0.3539 - val_accuracy: 0.8500
# Epoch 175/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4091 - accuracy: 0.8200 - val_loss: 0.3516 - val_accuracy: 0.8500
# Epoch 176/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4058 - accuracy: 0.8225 - val_loss: 0.3894 - val_accuracy: 0.8400
# Epoch 177/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4078 - accuracy: 0.8288 - val_loss: 0.3737 - val_accuracy: 0.8350
# Epoch 178/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4067 - accuracy: 0.8275 - val_loss: 0.4330 - val_accuracy: 0.8200
# Epoch 179/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4111 - accuracy: 0.8225 - val_loss: 0.3743 - val_accuracy: 0.8350
# Epoch 180/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4048 - accuracy: 0.8313 - val_loss: 0.3853 - val_accuracy: 0.8300
# Epoch 181/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4119 - accuracy: 0.8125 - val_loss: 0.3521 - val_accuracy: 0.8550
# Epoch 182/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4096 - accuracy: 0.8263 - val_loss: 0.3478 - val_accuracy: 0.8500
# Epoch 183/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8263 - val_loss: 0.3829 - val_accuracy: 0.8350
# Epoch 184/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4021 - accuracy: 0.8338 - val_loss: 0.3955 - val_accuracy: 0.8300
# Epoch 185/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4091 - accuracy: 0.8200 - val_loss: 0.4407 - val_accuracy: 0.8050
# Epoch 186/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4120 - accuracy: 0.8275 - val_loss: 0.3562 - val_accuracy: 0.8450
# Epoch 187/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.8250 - val_loss: 0.3604 - val_accuracy: 0.8450
# Epoch 188/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4069 - accuracy: 0.8313 - val_loss: 0.3593 - val_accuracy: 0.8500
# Epoch 189/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4083 - accuracy: 0.8300 - val_loss: 0.3531 - val_accuracy: 0.8500
# Epoch 190/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4092 - accuracy: 0.8250 - val_loss: 0.3594 - val_accuracy: 0.8400
# Epoch 191/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4082 - accuracy: 0.8238 - val_loss: 0.3734 - val_accuracy: 0.8400
# Epoch 192/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4052 - accuracy: 0.8250 - val_loss: 0.4081 - val_accuracy: 0.8200
# Epoch 193/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4056 - accuracy: 0.8275 - val_loss: 0.3801 - val_accuracy: 0.8500
# Epoch 194/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4143 - accuracy: 0.8188 - val_loss: 0.3536 - val_accuracy: 0.8500
# Epoch 195/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4053 - accuracy: 0.8150 - val_loss: 0.3691 - val_accuracy: 0.8350
# Epoch 196/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4093 - accuracy: 0.8288 - val_loss: 0.3584 - val_accuracy: 0.8400
# Epoch 197/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4103 - accuracy: 0.8250 - val_loss: 0.3790 - val_accuracy: 0.8300
# Epoch 198/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4052 - accuracy: 0.8138 - val_loss: 0.3590 - val_accuracy: 0.8500
# Epoch 199/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4030 - accuracy: 0.8288 - val_loss: 0.3504 - val_accuracy: 0.8500
# Epoch 200/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4050 - accuracy: 0.8250 - val_loss: 0.3552 - val_accuracy: 0.8550
# Time taken: 20.87s

# %% [markdown]
# Expected output:
# ```
# Epoch 1/200
# 25/25 [==============================] - 1s 10ms/step - loss: 0.8676 - accuracy: 0.6388 - val_loss: 0.6800 - val_accuracy: 0.7900
# Epoch 2/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6229 - accuracy: 0.7387 - val_loss: 0.5251 - val_accuracy: 0.8400
# Epoch 3/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5706 - accuracy: 0.7462 - val_loss: 0.5307 - val_accuracy: 0.8350
# ...
# Time taken: 20.93s
# ```
# You shall have `25/25 [==============================]` for every epoch, though the loss, accuracy, val_loss, val_accuracy might be different. Your 'Time taken' should be in the same level without using any accelerator (GPU or TPU).
#
# The final output need to be greater than `0.8`.
#
# Now, let's print the history out.

# %%
# plot training history
pyplot.plot(history32.history['accuracy'], label='train')
pyplot.plot(history32.history['val_accuracy'], label='validation')
pyplot.xlabel('epoch number')
pyplot.ylabel('accuracy')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ###2.6 Conclusion
# To give you a more straightforward comparison of the three methods, we print the training histories of three methods all together.

# %%
pyplot.figure(figsize=(15,4))

pyplot.subplot(1,3,1)
pyplot.plot(historyGD.history['accuracy'], label='train')
pyplot.plot(historyGD.history['val_accuracy'], label='test')
pyplot.xlabel('epoch number')
pyplot.ylabel('accuracy')
pyplot.legend()
pyplot.title('GD, batch_size=800')

pyplot.subplot(1,3,2)
pyplot.plot(historySGD.history['accuracy'], label='train')
pyplot.plot(historySGD.history['val_accuracy'], label='test')
pyplot.title('SGD, batch_size=1')
pyplot.xlabel('epoch number')
pyplot.ylabel('accuracy')
pyplot.legend()


pyplot.subplot(1,3,3)
pyplot.plot(history32.history['accuracy'], label='train')
pyplot.plot(history32.history['val_accuracy'], label='test')
pyplot.title('mini-batch GD, batch_size=32')
pyplot.xlabel('epoch number')
pyplot.ylabel('accuracy')
pyplot.legend()
pyplot.show()

# %% [markdown]
# Basically, large batch_size means more stable performance, and small (but not too small) batch_size means achieving the same level of performance within less epochs. Meanwhile, we also notice that with large batch_size, we can finish the same number of epochs in less time. In practice, you will need to adjust the batch_size to balance all the affect.
